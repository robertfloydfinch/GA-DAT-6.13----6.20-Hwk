# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

data = pd.read_csv('data/zomato.csv', encoding = "ISO-8859-1")
df = pd.DataFrame(data)

sns.boxplot(x='Price_range', y='Aggregate_rating', data=data, width=.5)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

data = pd.read_csv('data/zomato.csv', encoding = "ISO-8859-1")
df = pd.DataFrame(data)
df.describe(exclude=[np.object])
# Out:
#        Restaurant_ID  Country_Code    Longitude     Latitude  \
# count   9.508000e+03   9508.000000  9508.000000  9508.000000
# mean    9.054305e+06     17.500421    64.393070    25.796607
# std     8.805745e+06     55.397272    41.223619    10.995356
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.018948e+05      1.000000    77.082045    28.478168
# 50%     6.104071e+06      1.000000    77.192960    28.570240
# 75%     1.835305e+07      1.000000    77.282254    28.642451
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average_Cost_for_two  Price_range  Aggregate_rating         Votes
# count           9508.000000  9508.000000       9508.000000   9508.000000
# mean            1204.314998     1.801325          2.659392    155.789756
# std            16157.420202     0.904258          1.515999    430.014072
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     30.000000
# 75%              700.000000     2.000000          3.700000    129.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
df.groupby('Country').Price_range.describe()
# Out:
#                  count      mean       std  min  25%  50%   75%  max
# Country
# Australia         24.0  2.125000  0.740887  1.0  2.0  2.0  2.25  4.0
# Brazil            60.0  3.400000  0.827494  1.0  3.0  4.0  4.00  4.0
# Canada             4.0  2.500000  1.000000  2.0  2.0  2.0  2.50  4.0
# India           8652.0  1.721683  0.852544  1.0  1.0  2.0  2.00  4.0
# Indonesia         21.0  2.952381  0.218218  2.0  3.0  3.0  3.00  3.0
# New Zealand       40.0  3.150000  0.892993  1.0  3.0  3.0  4.00  4.0
# Phillipines       22.0  3.363636  0.581087  2.0  3.0  3.0  4.00  4.0
# Qatar             20.0  3.650000  0.587143  2.0  3.0  4.0  4.00  4.0
# Singapore         20.0  3.650000  0.587143  2.0  3.0  4.0  4.00  4.0
# South Africa      60.0  3.583333  0.618683  2.0  3.0  4.0  4.00  4.0
# Sri Lanka         20.0  2.850000  0.670820  2.0  2.0  3.0  3.00  4.0
# UAE               60.0  3.216667  0.691147  2.0  3.0  3.0  4.00  4.0
# United Kingdom    80.0  2.750000  0.834388  1.0  2.0  3.0  3.00  4.0
# United States    425.0  2.054118  0.879209  1.0  1.0  2.0  3.00  4.0

# %%
df.groupby('Country').Aggregate_rating.describe()
# Out:
#                  count      mean       std  min    25%   50%    75%  max
# Country
# Australia         24.0  3.658333  0.523298  2.4  3.500  3.70  3.875  4.6
# Brazil            60.0  3.763333  1.253195  0.0  3.600  4.15  4.500  4.9
# Canada             4.0  3.575000  0.561991  3.0  3.225  3.50  3.850  4.3
# India           8652.0  2.523324  1.510986  0.0  2.100  3.10  3.600  4.9
# Indonesia         21.0  4.295238  0.428341  3.4  4.000  4.30  4.600  4.9
# New Zealand       40.0  4.262500  0.433050  2.3  4.100  4.30  4.500  4.9
# Phillipines       22.0  4.468182  0.345566  3.6  4.225  4.50  4.800  4.9
# Qatar             20.0  4.060000  0.418519  3.4  3.800  4.00  4.325  4.9
# Singapore         20.0  3.575000  0.390512  3.0  3.200  3.75  3.900  4.2
# South Africa      60.0  4.210000  0.331765  3.4  4.000  4.20  4.400  4.9
# Sri Lanka         20.0  3.870000  0.590361  2.4  3.675  4.00  4.200  4.9
# UAE               60.0  4.233333  0.421726  2.4  4.000  4.25  4.500  4.9
# United Kingdom    80.0  4.087500  0.633331  0.0  3.875  4.10  4.500  4.9
# United States    425.0  4.007294  0.528765  0.0  3.700  4.10  4.300  4.9

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

sns.barplot(x="Votes", y="Country",
    palette=sns.color_palette(flatui),data=data,ci=None)
